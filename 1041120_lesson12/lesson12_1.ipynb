# %%
# 結構化程式

import requests
from requests import HTTPError,JSONDecodeError

def get_aqi()->list[dict] #自訂程式
    try:
        url = 'https://data.moenv.gov.tw/api/v2/aqx_p_432?api_key=af57253c-e838-46da-a1f5-12b43afd75f3&limit=1000&sort=ImportDate desc&format=JSON'
        response = requests.get(url,verify=False)
        response.raise_for_status()
        data_list:list= response.json()['records'] #data_list是每一個站的的資料
        return data_list
    except HTTPError as error:
        raise Exception(f"HTTPError:{error}")
    except JSONDecodeError:
        raise Exception(f"內容不是json的格式")
    except Exception:
        raise Exception("不知的錯誤")
    

def main(): #自定程式
    try:
        site_listdata = get_aqi()
    except Exception as error:
        print(error)
        return  #如果在function出錯了,直接return,'提早離開'
    else:
        print("下載成功")

    for site in site_listdata: #for in 迴圈
        print(site)

if __name__ == "__main__": #呼叫程式
    main() #顯示程式結果
# Out:
#   Cell In[1], line 6
#     def get_aqi()->list[dict] #自訂程式
#                               ^
# SyntaxError: expected ':'

# %%
import requests
from requests import HTTPError,JSONDecodeError
from pprint import pprint #第一個pprint是module第二個pprint是function

def get_aqi()->list[dict]:
    try:
        url = 'https://data.moenv.gov.tw/api/v2/aqx_p_432?api_key=af57253c-e838-46da-a1f5-12b43afd75f3&limit=1000&sort=ImportDate desc&format=JSON'
        response = requests.get(url,verify=False)
        response.raise_for_status()
        data_list:list= response.json()['records'] #data_list是每一個站的的資料
        return data_list
    except HTTPError as error:
        raise Exception(f"HTTPError:{error}")
    except JSONDecodeError:
        raise Exception(f"內容不是json的格式")
    except Exception:
        raise Exception("不知的錯誤")
    

def main():
    try:
        site_listdata = get_aqi() #site_data為變數名
    except Exception as error:
        print(error)
        return  #如果在function出錯了,直接return,'提早離開'
    else:
        print("下載成功")

    filter_data:list = []
    for site in site_listdata:
        new_site:dict = dict()
        new_site["站點名稱"] = site['sitename']
        new_site["城市名稱"] = site['county']
        new_site['aqi'] = site['aqi']
        new_site['狀態'] = site['status']
        filter_data.append(new_site) #.append()
    
    pprint(filter_data)

if __name__ == "__main__":
    main()
# Out:
# /opt/conda/lib/python3.13/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'data.moenv.gov.tw'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 下載成功
# [{'aqi': '55', '城市名稱': '基隆市', '狀態': '普通', '站點名稱': '基隆'},
#  {'aqi': '64', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '汐止'},
#  {'aqi': '57', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '新店'},
#  {'aqi': '56', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '土城'},
#  {'aqi': '65', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '板橋'},
#  {'aqi': '63', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '新莊'},
#  {'aqi': '57', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '菜寮'},
#  {'aqi': '61', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '林口'},
#  {'aqi': '58', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '淡水'},
#  {'aqi': '53', '城市名稱': '臺北市', '狀態': '普通', '站點名稱': '士林'},
#  {'aqi': '65', '城市名稱': '臺北市', '狀態': '普通', '站點名稱': '中山'},
#  {'aqi': '58', '城市名稱': '臺北市', '狀態': '普通', '站點名稱': '萬華'},
#  {'aqi': '55', '城市名稱': '臺北市', '狀態': '普通', '站點名稱': '古亭'},
#  {'aqi': '67', '城市名稱': '臺北市', '狀態': '普通', '站點名稱': '松山'},
#  {'aqi': '68', '城市名稱': '臺北市', '狀態': '普通', '站點名稱': '大同'},
#  {'aqi': '56', '城市名稱': '桃園市', '狀態': '普通', '站點名稱': '桃園'},
#  {'aqi': '61', '城市名稱': '桃園市', '狀態': '普通', '站點名稱': '大園'},
#  {'aqi': '60', '城市名稱': '桃園市', '狀態': '普通', '站點名稱': '觀音'},
#  {'aqi': '55', '城市名稱': '桃園市', '狀態': '普通', '站點名稱': '平鎮'},
#  {'aqi': '51', '城市名稱': '桃園市', '狀態': '普通', '站點名稱': '龍潭'},
#  {'aqi': '54', '城市名稱': '新竹縣', '狀態': '普通', '站點名稱': '湖口'},
#  {'aqi': '44', '城市名稱': '新竹縣', '狀態': '良好', '站點名稱': '竹東'},
#  {'aqi': '55', '城市名稱': '新竹市', '狀態': '普通', '站點名稱': '新竹'},
#  {'aqi': '52', '城市名稱': '苗栗縣', '狀態': '普通', '站點名稱': '頭份'},
#  {'aqi': '51', '城市名稱': '苗栗縣', '狀態': '普通', '站點名稱': '苗栗'},
#  {'aqi': '40', '城市名稱': '苗栗縣', '狀態': '良好', '站點名稱': '三義'},
#  {'aqi': '47', '城市名稱': '臺中市', '狀態': '良好', '站點名稱': '豐原'},
#  {'aqi': '58', '城市名稱': '臺中市', '狀態': '普通', '站點名稱': '沙鹿'},
#  {'aqi': '48', '城市名稱': '臺中市', '狀態': '良好', '站點名稱': '大里'},
#  {'aqi': '50', '城市名稱': '臺中市', '狀態': '良好', '站點名稱': '忠明'},
#  {'aqi': '53', '城市名稱': '臺中市', '狀態': '普通', '站點名稱': '西屯'},
#  {'aqi': '57', '城市名稱': '彰化縣', '狀態': '普通', '站點名稱': '彰化'},
#  {'aqi': '61', '城市名稱': '彰化縣', '狀態': '普通', '站點名稱': '線西'},
#  {'aqi': '79', '城市名稱': '彰化縣', '狀態': '普通', '站點名稱': '二林'},
#  {'aqi': '', '城市名稱': '南投縣', '狀態': '', '站點名稱': '南投'},
#  {'aqi': '78', '城市名稱': '雲林縣', '狀態': '普通', '站點名稱': '斗六'},
#  {'aqi': '69', '城市名稱': '雲林縣', '狀態': '普通', '站點名稱': '崙背'},
#  {'aqi': '73', '城市名稱': '嘉義縣', '狀態': '普通', '站點名稱': '新港'},
#  {'aqi': '74', '城市名稱': '嘉義縣', '狀態': '普通', '站點名稱': '朴子'},
#  {'aqi': '63', '城市名稱': '雲林縣', '狀態': '普通', '站點名稱': '臺西'},
#  {'aqi': '72', '城市名稱': '嘉義市', '狀態': '普通', '站點名稱': '嘉義'},
#  {'aqi': '78', '城市名稱': '臺南市', '狀態': '普通', '站點名稱': '新營'},
#  {'aqi': '75', '城市名稱': '臺南市', '狀態': '普通', '站點名稱': '善化'},
#  {'aqi': '83', '城市名稱': '臺南市', '狀態': '普通', '站點名稱': '安南'},
#  {'aqi': '87', '城市名稱': '臺南市', '狀態': '普通', '站點名稱': '臺南'},
#  {'aqi': '71', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '美濃'},
#  {'aqi': '91', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '橋頭'},
#  {'aqi': '78', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '仁武'},
#  {'aqi': '95', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '鳳山'},
#  {'aqi': '93', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '大寮'},
#  {'aqi': '101', '城市名稱': '高雄市', '狀態': '對敏感族群不健康', '站點名稱': '林園'},
#  {'aqi': '86', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '楠梓'},
#  {'aqi': '91', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '左營'},
#  {'aqi': '91', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '前金'},
#  {'aqi': '91', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '前鎮'},
#  {'aqi': '91', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '小港'},
#  {'aqi': '72', '城市名稱': '屏東縣', '狀態': '普通', '站點名稱': '屏東'},
#  {'aqi': '91', '城市名稱': '屏東縣', '狀態': '普通', '站點名稱': '潮州'},
#  {'aqi': '43', '城市名稱': '屏東縣', '狀態': '良好', '站點名稱': '恆春'},
#  {'aqi': '54', '城市名稱': '臺東縣', '狀態': '普通', '站點名稱': '臺東'},
#  {'aqi': '37', '城市名稱': '花蓮縣', '狀態': '良好', '站點名稱': '花蓮'},
#  {'aqi': '41', '城市名稱': '臺北市', '狀態': '良好', '站點名稱': '陽明'},
#  {'aqi': '42', '城市名稱': '宜蘭縣', '狀態': '良好', '站點名稱': '宜蘭'},
#  {'aqi': '50', '城市名稱': '宜蘭縣', '狀態': '良好', '站點名稱': '冬山'},
#  {'aqi': '72', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '三重'},
#  {'aqi': '63', '城市名稱': '桃園市', '狀態': '普通', '站點名稱': '中壢'},
#  {'aqi': '66', '城市名稱': '南投縣', '狀態': '普通', '站點名稱': '竹山'},
#  {'aqi': '64', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '永和'},
#  {'aqi': '85', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '復興'},
#  {'aqi': '61', '城市名稱': '南投縣', '狀態': '普通', '站點名稱': '埔里'},
#  {'aqi': '67', '城市名稱': '連江縣', '狀態': '普通', '站點名稱': '馬祖'},
#  {'aqi': '74', '城市名稱': '金門縣', '狀態': '普通', '站點名稱': '金門'},
#  {'aqi': '64', '城市名稱': '澎湖縣', '狀態': '普通', '站點名稱': '馬公'},
#  {'aqi': '42', '城市名稱': '臺東縣', '狀態': '良好', '站點名稱': '關山'},
#  {'aqi': '69', '城市名稱': '雲林縣', '狀態': '普通', '站點名稱': '麥寮'},
#  {'aqi': '65', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '富貴角'},
#  {'aqi': '65', '城市名稱': '彰化縣', '狀態': '普通', '站點名稱': '大城'},
#  {'aqi': '58', '城市名稱': '彰化縣', '狀態': '普通', '站點名稱': '員林'},
#  {'aqi': '25', '城市名稱': '宜蘭縣', '狀態': '良好', '站點名稱': '宜蘭（三星）'},
#  {'aqi': '87', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '高雄（湖內）'},
#  {'aqi': '66', '城市名稱': '南投縣', '狀態': '普通', '站點名稱': '南投（鹿谷）'},
#  {'aqi': '87', '城市名稱': '屏東縣', '狀態': '普通', '站點名稱': '屏東（琉球）'},
#  {'aqi': '47', '城市名稱': '臺中市', '狀態': '良好', '站點名稱': '台中市（和平區）'},
#  {'aqi': '58', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '新北(樹林)'},
#  {'aqi': '69', '城市名稱': '臺南市', '狀態': '普通', '站點名稱': '臺南（南化）'},
#  {'aqi': '62', '城市名稱': '屏東縣', '狀態': '普通', '站點名稱': '屏東(枋山)'}]

# %%
import requests
from requests import HTTPError,JSONDecodeError
from pprint import pprint

def get_aqi()->list[dict]:
    try:
        url = 'https://data.moenv.gov.tw/api/v2/aqx_p_432?api_key=af57253c-e838-46da-a1f5-12b43afd75f3&limit=1000&sort=ImportDate desc&format=JSON'
        response = requests.get(url,verify=False)
        response.raise_for_status()
        data_list:list= response.json()['records'] #data_list是每一個站的的資料
        return data_list
    except HTTPError as error:
        raise Exception(f"HTTPError:{error}")
    except JSONDecodeError:
        raise Exception(f"內容不是json的格式")
    except Exception:
        raise Exception("不知的錯誤")

def filter_data(site_list:list[dict])->list[dict]:
    '''過濾資料,只要sitename,country,aqi,status'''
    filter_data:list = []
    for site in site_list:
        new_site:dict = dict()
        new_site["站點名稱"] = site['sitename']
        new_site["城市名稱"] = site['county']
        new_site['aqi'] = site['aqi']
        new_site['狀態'] = site['status']
        filter_data.append(new_site)
    return filter_data

    
def main():
    # 下載資料
    try:
        site_listdata = get_aqi()
    except Exception as error:
        print(error)
        return  #如果在function出錯了,直接return,'提早離開'
    else:
        print("下載成功")

    # 過濾資料
    allsitelistdatas = filter_data(site_listdata)  

    #顯示資料   
    pprint(allsitelistdatas) #利用python裡的funcion顯示資料

#執行主程式
if __name__ == "__main__":
    main()
# Out:
# /opt/conda/lib/python3.13/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'data.moenv.gov.tw'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 下載成功
# [{'aqi': '55', '城市名稱': '基隆市', '狀態': '普通', '站點名稱': '基隆'},
#  {'aqi': '64', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '汐止'},
#  {'aqi': '57', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '新店'},
#  {'aqi': '56', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '土城'},
#  {'aqi': '65', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '板橋'},
#  {'aqi': '63', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '新莊'},
#  {'aqi': '57', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '菜寮'},
#  {'aqi': '61', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '林口'},
#  {'aqi': '58', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '淡水'},
#  {'aqi': '53', '城市名稱': '臺北市', '狀態': '普通', '站點名稱': '士林'},
#  {'aqi': '65', '城市名稱': '臺北市', '狀態': '普通', '站點名稱': '中山'},
#  {'aqi': '58', '城市名稱': '臺北市', '狀態': '普通', '站點名稱': '萬華'},
#  {'aqi': '55', '城市名稱': '臺北市', '狀態': '普通', '站點名稱': '古亭'},
#  {'aqi': '67', '城市名稱': '臺北市', '狀態': '普通', '站點名稱': '松山'},
#  {'aqi': '68', '城市名稱': '臺北市', '狀態': '普通', '站點名稱': '大同'},
#  {'aqi': '56', '城市名稱': '桃園市', '狀態': '普通', '站點名稱': '桃園'},
#  {'aqi': '61', '城市名稱': '桃園市', '狀態': '普通', '站點名稱': '大園'},
#  {'aqi': '60', '城市名稱': '桃園市', '狀態': '普通', '站點名稱': '觀音'},
#  {'aqi': '55', '城市名稱': '桃園市', '狀態': '普通', '站點名稱': '平鎮'},
#  {'aqi': '51', '城市名稱': '桃園市', '狀態': '普通', '站點名稱': '龍潭'},
#  {'aqi': '54', '城市名稱': '新竹縣', '狀態': '普通', '站點名稱': '湖口'},
#  {'aqi': '44', '城市名稱': '新竹縣', '狀態': '良好', '站點名稱': '竹東'},
#  {'aqi': '55', '城市名稱': '新竹市', '狀態': '普通', '站點名稱': '新竹'},
#  {'aqi': '52', '城市名稱': '苗栗縣', '狀態': '普通', '站點名稱': '頭份'},
#  {'aqi': '51', '城市名稱': '苗栗縣', '狀態': '普通', '站點名稱': '苗栗'},
#  {'aqi': '40', '城市名稱': '苗栗縣', '狀態': '良好', '站點名稱': '三義'},
#  {'aqi': '47', '城市名稱': '臺中市', '狀態': '良好', '站點名稱': '豐原'},
#  {'aqi': '58', '城市名稱': '臺中市', '狀態': '普通', '站點名稱': '沙鹿'},
#  {'aqi': '48', '城市名稱': '臺中市', '狀態': '良好', '站點名稱': '大里'},
#  {'aqi': '50', '城市名稱': '臺中市', '狀態': '良好', '站點名稱': '忠明'},
#  {'aqi': '53', '城市名稱': '臺中市', '狀態': '普通', '站點名稱': '西屯'},
#  {'aqi': '57', '城市名稱': '彰化縣', '狀態': '普通', '站點名稱': '彰化'},
#  {'aqi': '61', '城市名稱': '彰化縣', '狀態': '普通', '站點名稱': '線西'},
#  {'aqi': '79', '城市名稱': '彰化縣', '狀態': '普通', '站點名稱': '二林'},
#  {'aqi': '', '城市名稱': '南投縣', '狀態': '', '站點名稱': '南投'},
#  {'aqi': '78', '城市名稱': '雲林縣', '狀態': '普通', '站點名稱': '斗六'},
#  {'aqi': '69', '城市名稱': '雲林縣', '狀態': '普通', '站點名稱': '崙背'},
#  {'aqi': '73', '城市名稱': '嘉義縣', '狀態': '普通', '站點名稱': '新港'},
#  {'aqi': '74', '城市名稱': '嘉義縣', '狀態': '普通', '站點名稱': '朴子'},
#  {'aqi': '63', '城市名稱': '雲林縣', '狀態': '普通', '站點名稱': '臺西'},
#  {'aqi': '72', '城市名稱': '嘉義市', '狀態': '普通', '站點名稱': '嘉義'},
#  {'aqi': '78', '城市名稱': '臺南市', '狀態': '普通', '站點名稱': '新營'},
#  {'aqi': '75', '城市名稱': '臺南市', '狀態': '普通', '站點名稱': '善化'},
#  {'aqi': '83', '城市名稱': '臺南市', '狀態': '普通', '站點名稱': '安南'},
#  {'aqi': '87', '城市名稱': '臺南市', '狀態': '普通', '站點名稱': '臺南'},
#  {'aqi': '71', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '美濃'},
#  {'aqi': '91', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '橋頭'},
#  {'aqi': '78', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '仁武'},
#  {'aqi': '95', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '鳳山'},
#  {'aqi': '93', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '大寮'},
#  {'aqi': '101', '城市名稱': '高雄市', '狀態': '對敏感族群不健康', '站點名稱': '林園'},
#  {'aqi': '86', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '楠梓'},
#  {'aqi': '91', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '左營'},
#  {'aqi': '91', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '前金'},
#  {'aqi': '91', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '前鎮'},
#  {'aqi': '91', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '小港'},
#  {'aqi': '72', '城市名稱': '屏東縣', '狀態': '普通', '站點名稱': '屏東'},
#  {'aqi': '91', '城市名稱': '屏東縣', '狀態': '普通', '站點名稱': '潮州'},
#  {'aqi': '43', '城市名稱': '屏東縣', '狀態': '良好', '站點名稱': '恆春'},
#  {'aqi': '54', '城市名稱': '臺東縣', '狀態': '普通', '站點名稱': '臺東'},
#  {'aqi': '37', '城市名稱': '花蓮縣', '狀態': '良好', '站點名稱': '花蓮'},
#  {'aqi': '41', '城市名稱': '臺北市', '狀態': '良好', '站點名稱': '陽明'},
#  {'aqi': '42', '城市名稱': '宜蘭縣', '狀態': '良好', '站點名稱': '宜蘭'},
#  {'aqi': '50', '城市名稱': '宜蘭縣', '狀態': '良好', '站點名稱': '冬山'},
#  {'aqi': '72', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '三重'},
#  {'aqi': '63', '城市名稱': '桃園市', '狀態': '普通', '站點名稱': '中壢'},
#  {'aqi': '66', '城市名稱': '南投縣', '狀態': '普通', '站點名稱': '竹山'},
#  {'aqi': '64', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '永和'},
#  {'aqi': '85', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '復興'},
#  {'aqi': '61', '城市名稱': '南投縣', '狀態': '普通', '站點名稱': '埔里'},
#  {'aqi': '67', '城市名稱': '連江縣', '狀態': '普通', '站點名稱': '馬祖'},
#  {'aqi': '74', '城市名稱': '金門縣', '狀態': '普通', '站點名稱': '金門'},
#  {'aqi': '64', '城市名稱': '澎湖縣', '狀態': '普通', '站點名稱': '馬公'},
#  {'aqi': '42', '城市名稱': '臺東縣', '狀態': '良好', '站點名稱': '關山'},
#  {'aqi': '69', '城市名稱': '雲林縣', '狀態': '普通', '站點名稱': '麥寮'},
#  {'aqi': '65', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '富貴角'},
#  {'aqi': '65', '城市名稱': '彰化縣', '狀態': '普通', '站點名稱': '大城'},
#  {'aqi': '58', '城市名稱': '彰化縣', '狀態': '普通', '站點名稱': '員林'},
#  {'aqi': '25', '城市名稱': '宜蘭縣', '狀態': '良好', '站點名稱': '宜蘭（三星）'},
#  {'aqi': '87', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '高雄（湖內）'},
#  {'aqi': '66', '城市名稱': '南投縣', '狀態': '普通', '站點名稱': '南投（鹿谷）'},
#  {'aqi': '87', '城市名稱': '屏東縣', '狀態': '普通', '站點名稱': '屏東（琉球）'},
#  {'aqi': '47', '城市名稱': '臺中市', '狀態': '良好', '站點名稱': '台中市（和平區）'},
#  {'aqi': '58', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '新北(樹林)'},
#  {'aqi': '69', '城市名稱': '臺南市', '狀態': '普通', '站點名稱': '臺南（南化）'},
#  {'aqi': '62', '城市名稱': '屏東縣', '狀態': '普通', '站點名稱': '屏東(枋山)'}]

# %%
import requests
from requests import HTTPError,JSONDecodeError
from pprint import pprint

def get_aqi()->list[dict]:
    try:
        url = 'https://data.moenv.gov.tw/api/v2/aqx_p_432?api_key=af57253c-e838-46da-a1f5-12b43afd75f3&limit=1000&sort=ImportDate desc&format=JSON'
        response = requests.get(url,verify=False)
        response.raise_for_status()
        data_list:list= response.json()['records'] #data_list是每一個站的的資料
        return data_list
    except HTTPError as e:
        raise Exception(f"HTTPError:{e}")
    except JSONDecodeError:
        raise Exception(f"內容不是json的格式")
    except Exception:
        raise Exception("不知的錯誤")

def filter_data(site_list:list[dict])->list[dict]:
    '''過濾資料,只要sitename,country,aqi,status'''
    filter_data:list = []
    for site in site_list:
        new_site:dict = dict()
        new_site["站點名稱"] = site['sitename']
        new_site["城市名稱"] = site['county']
        new_site['aqi'] = site['aqi']
        new_site['狀態'] = site['status']
        filter_data.append(new_site)
    return filter_data

def save_csv(data:list[dict]):
    pprint(data)


def main():
    # 下載資料
    try:
        site_list = get_aqi()
    except Exception as error:
        print(error)
        return  #如果在function出錯了,直接return,'提早離開'
    else:
        print("下載成功")

    # 過濾資料
    sites = filter_data(site_list)     
    
    # 儲存成csv檔
    save_csv(sites)

if __name__ == "__main__":
    main()
# Out:
# /opt/conda/lib/python3.13/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'data.moenv.gov.tw'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 下載成功
# [{'aqi': '54', '城市名稱': '基隆市', '狀態': '普通', '站點名稱': '基隆'},
#  {'aqi': '62', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '汐止'},
#  {'aqi': '58', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '新店'},
#  {'aqi': '56', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '土城'},
#  {'aqi': '66', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '板橋'},
#  {'aqi': '63', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '新莊'},
#  {'aqi': '57', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '菜寮'},
#  {'aqi': '61', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '林口'},
#  {'aqi': '55', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '淡水'},
#  {'aqi': '53', '城市名稱': '臺北市', '狀態': '普通', '站點名稱': '士林'},
#  {'aqi': '63', '城市名稱': '臺北市', '狀態': '普通', '站點名稱': '中山'},
#  {'aqi': '59', '城市名稱': '臺北市', '狀態': '普通', '站點名稱': '萬華'},
#  {'aqi': '57', '城市名稱': '臺北市', '狀態': '普通', '站點名稱': '古亭'},
#  {'aqi': '65', '城市名稱': '臺北市', '狀態': '普通', '站點名稱': '松山'},
#  {'aqi': '67', '城市名稱': '臺北市', '狀態': '普通', '站點名稱': '大同'},
#  {'aqi': '55', '城市名稱': '桃園市', '狀態': '普通', '站點名稱': '桃園'},
#  {'aqi': '59', '城市名稱': '桃園市', '狀態': '普通', '站點名稱': '大園'},
#  {'aqi': '58', '城市名稱': '桃園市', '狀態': '普通', '站點名稱': '觀音'},
#  {'aqi': '58', '城市名稱': '桃園市', '狀態': '普通', '站點名稱': '平鎮'},
#  {'aqi': '48', '城市名稱': '桃園市', '狀態': '良好', '站點名稱': '龍潭'},
#  {'aqi': '55', '城市名稱': '新竹縣', '狀態': '普通', '站點名稱': '湖口'},
#  {'aqi': '42', '城市名稱': '新竹縣', '狀態': '良好', '站點名稱': '竹東'},
#  {'aqi': '57', '城市名稱': '新竹市', '狀態': '普通', '站點名稱': '新竹'},
#  {'aqi': '52', '城市名稱': '苗栗縣', '狀態': '普通', '站點名稱': '頭份'},
#  {'aqi': '52', '城市名稱': '苗栗縣', '狀態': '普通', '站點名稱': '苗栗'},
#  {'aqi': '44', '城市名稱': '苗栗縣', '狀態': '良好', '站點名稱': '三義'},
#  {'aqi': '46', '城市名稱': '臺中市', '狀態': '良好', '站點名稱': '豐原'},
#  {'aqi': '57', '城市名稱': '臺中市', '狀態': '普通', '站點名稱': '沙鹿'},
#  {'aqi': '48', '城市名稱': '臺中市', '狀態': '良好', '站點名稱': '大里'},
#  {'aqi': '50', '城市名稱': '臺中市', '狀態': '良好', '站點名稱': '忠明'},
#  {'aqi': '53', '城市名稱': '臺中市', '狀態': '普通', '站點名稱': '西屯'},
#  {'aqi': '57', '城市名稱': '彰化縣', '狀態': '普通', '站點名稱': '彰化'},
#  {'aqi': '60', '城市名稱': '彰化縣', '狀態': '普通', '站點名稱': '線西'},
#  {'aqi': '78', '城市名稱': '彰化縣', '狀態': '普通', '站點名稱': '二林'},
#  {'aqi': '', '城市名稱': '南投縣', '狀態': '', '站點名稱': '南投'},
#  {'aqi': '75', '城市名稱': '雲林縣', '狀態': '普通', '站點名稱': '斗六'},
#  {'aqi': '70', '城市名稱': '雲林縣', '狀態': '普通', '站點名稱': '崙背'},
#  {'aqi': '69', '城市名稱': '嘉義縣', '狀態': '普通', '站點名稱': '新港'},
#  {'aqi': '72', '城市名稱': '嘉義縣', '狀態': '普通', '站點名稱': '朴子'},
#  {'aqi': '64', '城市名稱': '雲林縣', '狀態': '普通', '站點名稱': '臺西'},
#  {'aqi': '73', '城市名稱': '嘉義市', '狀態': '普通', '站點名稱': '嘉義'},
#  {'aqi': '77', '城市名稱': '臺南市', '狀態': '普通', '站點名稱': '新營'},
#  {'aqi': '74', '城市名稱': '臺南市', '狀態': '普通', '站點名稱': '善化'},
#  {'aqi': '82', '城市名稱': '臺南市', '狀態': '普通', '站點名稱': '安南'},
#  {'aqi': '86', '城市名稱': '臺南市', '狀態': '普通', '站點名稱': '臺南'},
#  {'aqi': '77', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '美濃'},
#  {'aqi': '93', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '橋頭'},
#  {'aqi': '81', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '仁武'},
#  {'aqi': '95', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '鳳山'},
#  {'aqi': '96', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '大寮'},
#  {'aqi': '105', '城市名稱': '高雄市', '狀態': '對敏感族群不健康', '站點名稱': '林園'},
#  {'aqi': '89', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '楠梓'},
#  {'aqi': '95', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '左營'},
#  {'aqi': '92', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '前金'},
#  {'aqi': '92', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '前鎮'},
#  {'aqi': '95', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '小港'},
#  {'aqi': '71', '城市名稱': '屏東縣', '狀態': '普通', '站點名稱': '屏東'},
#  {'aqi': '90', '城市名稱': '屏東縣', '狀態': '普通', '站點名稱': '潮州'},
#  {'aqi': '43', '城市名稱': '屏東縣', '狀態': '良好', '站點名稱': '恆春'},
#  {'aqi': '64', '城市名稱': '臺東縣', '狀態': '普通', '站點名稱': '臺東'},
#  {'aqi': '37', '城市名稱': '花蓮縣', '狀態': '良好', '站點名稱': '花蓮'},
#  {'aqi': '41', '城市名稱': '臺北市', '狀態': '良好', '站點名稱': '陽明'},
#  {'aqi': '42', '城市名稱': '宜蘭縣', '狀態': '良好', '站點名稱': '宜蘭'},
#  {'aqi': '52', '城市名稱': '宜蘭縣', '狀態': '普通', '站點名稱': '冬山'},
#  {'aqi': '71', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '三重'},
#  {'aqi': '63', '城市名稱': '桃園市', '狀態': '普通', '站點名稱': '中壢'},
#  {'aqi': '66', '城市名稱': '南投縣', '狀態': '普通', '站點名稱': '竹山'},
#  {'aqi': '61', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '永和'},
#  {'aqi': '87', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '復興'},
#  {'aqi': '63', '城市名稱': '南投縣', '狀態': '普通', '站點名稱': '埔里'},
#  {'aqi': '72', '城市名稱': '連江縣', '狀態': '普通', '站點名稱': '馬祖'},
#  {'aqi': '77', '城市名稱': '金門縣', '狀態': '普通', '站點名稱': '金門'},
#  {'aqi': '63', '城市名稱': '澎湖縣', '狀態': '普通', '站點名稱': '馬公'},
#  {'aqi': '43', '城市名稱': '臺東縣', '狀態': '良好', '站點名稱': '關山'},
#  {'aqi': '68', '城市名稱': '雲林縣', '狀態': '普通', '站點名稱': '麥寮'},
#  {'aqi': '65', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '富貴角'},
#  {'aqi': '65', '城市名稱': '彰化縣', '狀態': '普通', '站點名稱': '大城'},
#  {'aqi': '55', '城市名稱': '彰化縣', '狀態': '普通', '站點名稱': '員林'},
#  {'aqi': '25', '城市名稱': '宜蘭縣', '狀態': '良好', '站點名稱': '宜蘭（三星）'},
#  {'aqi': '88', '城市名稱': '高雄市', '狀態': '普通', '站點名稱': '高雄（湖內）'},
#  {'aqi': '63', '城市名稱': '南投縣', '狀態': '普通', '站點名稱': '南投（鹿谷）'},
#  {'aqi': '89', '城市名稱': '屏東縣', '狀態': '普通', '站點名稱': '屏東（琉球）'},
#  {'aqi': '43', '城市名稱': '臺中市', '狀態': '良好', '站點名稱': '台中市（和平區）'},
#  {'aqi': '59', '城市名稱': '新北市', '狀態': '普通', '站點名稱': '新北(樹林)'},
#  {'aqi': '69', '城市名稱': '臺南市', '狀態': '普通', '站點名稱': '臺南（南化）'},
#  {'aqi': '58', '城市名稱': '屏東縣', '狀態': '普通', '站點名稱': '屏東(枋山)'}]

# %%
# 問完ai後調整的程式碼


import requests
from requests import HTTPError,JSONDecodeError
from pprint import pprint
import csv
from datetime import datetime

def get_aqi()->list[dict]:
    try:
        url = 'https://data.moenv.gov.tw/api/v2/aqx_p_432?api_key=af57253c-e838-46da-a1f5-12b43afd75f3&limit=1000&sort=ImportDate desc&format=JSON'
        response = requests.get(url,verify=False)
        response.raise_for_status()
        data_list:list= response.json()['records'] #data_list是每一個站的的資料
        return data_list
    except HTTPError as e:
        raise Exception(f"HTTPError:{e}")
    except JSONDecodeError:
        raise Exception(f"內容不是json的格式")
    except Exception:
        raise Exception("不知的錯誤")

def filter_data(site_list:list[dict])->list[dict]:
    '''過濾資料,只要sitename,country,aqi,status'''
    filter_data:list = []
    for site in site_list:
        new_site:dict = dict()
        new_site["站點名稱"] = site['sitename']
        new_site["城市名稱"] = site['county']
        new_site['aqi'] = site['aqi']
        new_site['狀態'] = site['status']
        filter_data.append(new_site)
    return filter_data

def save_csv(data:list[dict]): #儲存成csv檔
    # 產生檔案名稱(包含時間戳記)
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S") #取得目前時間並格式化
    filename = f"aqi_data_{timestamp}.csv" #檔案名稱格式為 aqi_data_年月日_時分秒.csv
    
    # 使用 csv.DictWriter 寫入資料
    if data:
        with open(filename, 'w', newline='', encoding='utf-8-sig') as csvfile:
            # 取得欄位名稱
            fieldnames = data[0].keys() #取得第一筆資料的鍵值作為欄位名稱
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames) #建立DictWriter物件
            
            # 寫入表頭
            writer.writeheader()
            
            # 寫入所有資料列
            writer.writerows(data)
        
        print(f"資料已儲存至 {filename}")
    else:
        print("沒有資料可儲存")
    
   

def main():
    # 下載資料
    try:
        site_list = get_aqi()
    except Exception as e:
        print(e)
        return  #如果在function出錯了,直接return,'提早離開'
    else:
        print("下載成功")

    # 過濾資料
    sites = filter_data(site_list)     
    
    # 儲存成csv檔
    save_csv(sites)

if __name__ == "__main__":
    main()
# Out:
# 下載成功
# 資料已儲存至 aqi_data_20251120_122908.csv
# /opt/conda/lib/python3.13/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'data.moenv.gov.tw'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
#進行ai優化後的最終版本

import requests
from requests import HTTPError, JSONDecodeError
from pprint import pprint
import csv
from datetime import datetime
import os

def fetch_aqi_data() -> list[dict]:
    """從環保署 API 獲取空氣品質指標資料"""
    try:
        url = 'https://data.moenv.gov.tw/api/v2/aqx_p_432?api_key=af57253c-e838-46da-a1f5-12b43afd75f3&limit=1000&sort=ImportDate desc&format=JSON'
        response = requests.get(url, verify=False)
        response.raise_for_status()
        records = response.json()['records']
        return records
    except HTTPError as error:
        raise Exception(f"HTTP 錯誤: {error}")
    except JSONDecodeError as error:
        raise Exception(f"JSON 解析錯誤: {str(error)}")
    except Exception as error:
        raise Exception(f"未知錯誤: {str(error)}")

def extract_site_info(sites: list[dict]) -> list[dict]:
    """提取站點的關鍵資訊（站名、城市、AQI、狀態）"""
    extracted_sites = []
    for site in sites:
        site_info = {
            "站點名稱": site['sitename'],
            "城市名稱": site['county'],
            "AQI": site['aqi'],
            "狀態": site['status']
        }
        extracted_sites.append(site_info)
    return extracted_sites

def export_to_csv(data: list[dict]) -> None:
    """將資料匯出為 CSV 檔案，檔案名稱包含時間戳記"""
    if not data:
        print("沒有資料可匯出")
        return
    
    try:
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        filename = f"aqi_data_{timestamp}.csv"
        
        with open(filename, 'w', newline='', encoding='utf-8-sig') as csvfile:
            fieldnames = data[0].keys()
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            
            writer.writeheader()
            writer.writerows(data)
        
        full_path = os.path.abspath(filename)
        print(f"資料已成功匯出至: {full_path}")
    except IOError as error:
        print(f"檔案寫入錯誤: {str(error)}")
    except Exception as error:
        print(f"匯出過程出錯: {str(error)}")

def main():
    """主程式：下載、提取、匯出空氣品質資料"""
    try:
        print("正在下載空氣品質資料...")
        aqi_records = fetch_aqi_data()
        print(f"成功下載 {len(aqi_records)} 筆資料")
    except Exception as error:
        print(f"下載失敗: {error}")
        return
    
    print("正在提取資訊...")
    site_info_list = extract_site_info(aqi_records)
    
    print("正在匯出 CSV...")
    export_to_csv(site_info_list)

if __name__ == "__main__":
    main()
# Out:
# 正在下載空氣品質資料...
# /opt/conda/lib/python3.13/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'data.moenv.gov.tw'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 成功下載 86 筆資料
# 正在提取資訊...
# 正在匯出 CSV...
# 資料已成功匯出至: /workspaces/python_ai_2/1041120_lesson12/aqi_data_20251120_124253.csv
