# %%
import numpy as np

students = np.random.randint(50, high=101, size=(50, 5))
students.shape
# Out:
# (50, 5)

# %%
# ndarray的實體方法
students.sum(axis=1)
students.mean(axis=1)
# Out:
# array([70.8, 72. , 69.8, 73.8, 59.4, 79.4, 69. , 73.8, 83.6, 73.2, 83.2,
#        83.8, 76.8, 80.6, 79.6, 69.8, 64.6, 82.6, 74.6, 82.6, 73.8, 77.8,
#        77.2, 57.8, 70. , 82.8, 83.2, 85.8, 80.2, 79.4, 83. , 68.6, 74.8,
#        68. , 68.8, 64.8, 79.4, 72.4, 72. , 64.6, 80. , 74. , 68. , 76. ,
#        76.2, 75.8, 78.6, 89.2, 76.8, 80.8])

# %%
# numpy內建的函式

np.sum(students, axis=1)
np.mean(students, axis=1)
# Out:
# array([70.8, 72. , 69.8, 73.8, 59.4, 79.4, 69. , 73.8, 83.6, 73.2, 83.2,
#        83.8, 76.8, 80.6, 79.6, 69.8, 64.6, 82.6, 74.6, 82.6, 73.8, 77.8,
#        77.2, 57.8, 70. , 82.8, 83.2, 85.8, 80.2, 79.4, 83. , 68.6, 74.8,
#        68. , 68.8, 64.8, 79.4, 72.4, 72. , 64.6, 80. , 74. , 68. , 76. ,
#        76.2, 75.8, 78.6, 89.2, 76.8, 80.8])

# %%
# 1家分站30天的營收

oneStore = np.random.randint(100, 10000, size=(30,))
oneStore
# Out:
# array([1952, 8847, 1614, 3313,  433,  916, 3293, 2288,  612, 5529, 5166,
#         463, 7704, 6680, 3673, 4765, 5227, 5073, 5607, 9690, 6858, 5868,
#        6311, 3848, 1327, 2246,  727, 2805, 7306, 6239])

# %%
# 累計每天這家店的營收
import matplotlib.pyplot as plt

oneStoreCum = oneStore.cumsum()
oneStoreCum

figure = plt.figure(figsize=(10, 5))
axes = figure.add_subplot(1,1,1)
axes.plot(range(1, 31), oneStoreCum, 'r-')
axes.set_title("one Store shop cumsum")
axes.set_xlabel("day")
axes.set_ylabel("money")
plt.show()
