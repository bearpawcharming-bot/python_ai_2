# %%
import numpy as np

students = np.random.randint(50, high=101, size=(50, 5))
students.shape
# Out:
# (50, 5)

# %%
# ndarray的實體方法
students.sum(axis=1)
students.mean(axis=1)
# Out:
# array([79.8, 68.2, 71.8, 70.2, 66. , 67.8, 73.4, 75.4, 79.2, 79.8, 68.4,
#        76.6, 85.2, 82.6, 91.8, 66.8, 89.8, 75.6, 72.8, 67.8, 70.8, 73. ,
#        69.6, 83.2, 70.2, 69.8, 79.2, 85.2, 71.4, 68.2, 75.8, 84.2, 81.2,
#        71.2, 75.8, 69. , 66.8, 80.4, 78. , 82.4, 77.6, 70.8, 82.6, 78.6,
#        83. , 65.2, 70.4, 78.6, 73.8, 67.6])

# %%
# numpy內建的函式

np.sum(students, axis=1)
np.mean(students, axis=1)
# Out:
# array([79.8, 68.2, 71.8, 70.2, 66. , 67.8, 73.4, 75.4, 79.2, 79.8, 68.4,
#        76.6, 85.2, 82.6, 91.8, 66.8, 89.8, 75.6, 72.8, 67.8, 70.8, 73. ,
#        69.6, 83.2, 70.2, 69.8, 79.2, 85.2, 71.4, 68.2, 75.8, 84.2, 81.2,
#        71.2, 75.8, 69. , 66.8, 80.4, 78. , 82.4, 77.6, 70.8, 82.6, 78.6,
#        83. , 65.2, 70.4, 78.6, 73.8, 67.6])

# %%
# 1家分站30天的營收

oneStore = np.random.randint(100, 10000, size=(30,))
oneStore
# Out:
# array([4572, 6651, 2952,  508, 1797, 3006, 1793, 6600, 6586, 1288, 1516,
#        3518, 4186,  692, 4352, 5809,  614, 7185, 4089, 6099, 9242, 1875,
#        6896, 8023, 1054, 7856, 4313, 4504, 6308, 7126])

# %%
# 累計每天這家店的營收
import matplotlib.pyplot as plt

oneStoreCum = oneStore.cumsum()
oneStoreCum

figure = plt.figure(figsize=(10, 5))
axes = figure.add_subplot(1,1,1)
axes.plot(range(1, 31), oneStoreCum, 'r-')
axes.set_title("one Store shop cumsum")
axes.set_xlabel("day")
axes.set_ylabel("money")
plt.show()
