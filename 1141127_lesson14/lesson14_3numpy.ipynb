# %%
import matplotlib as mpl
from matplotlib.font_manager import fontManager

fontManager.addfont("/Users/ylo/github/python_ai_2/1041127_lesson14/ChineseFont.ttf")
mpl.rc('font', family="ChineseFont")

# %%
import numpy as np
np.linspace(-3,3,50) # 產生-3到3之間的50個等距數值
# Out:
# array([-3.        , -2.87755102, -2.75510204, -2.63265306, -2.51020408,
#        -2.3877551 , -2.26530612, -2.14285714, -2.02040816, -1.89795918,
#        -1.7755102 , -1.65306122, -1.53061224, -1.40816327, -1.28571429,
#        -1.16326531, -1.04081633, -0.91836735, -0.79591837, -0.67346939,
#        -0.55102041, -0.42857143, -0.30612245, -0.18367347, -0.06122449,
#         0.06122449,  0.18367347,  0.30612245,  0.42857143,  0.55102041,
#         0.67346939,  0.79591837,  0.91836735,  1.04081633,  1.16326531,
#         1.28571429,  1.40816327,  1.53061224,  1.65306122,  1.7755102 ,
#         1.89795918,  2.02040816,  2.14285714,  2.26530612,  2.3877551 ,
#         2.51020408,  2.63265306,  2.75510204,  2.87755102,  3.        ])

# %%
import numpy as np
import matplotlib.pyplot as plt

# 指定間隔數量,傳出固定間隔的數字
x = np.linspace(-3, 3, 50)


# 陣列運算
y1 = 2 * x + 1
y2 = x ** 2

plt.plot(x, y1, color='red', label='y=2x+1', linewidth=2, linestyle='--')
plt.plot(x, y2, label='y=x^2', linewidth=2, color='blue', linestyle='-')

plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('Two Functions')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 指定間隔數量,傳出固定間隔的數字
x = np.linspace(-3, 3, 50)


# 陣列運算
y1 = 2 * x + 1
y2 = x ** 2

plt.plot(x, y1, color='red', label='y=2x+1', linewidth=2, linestyle='--')
plt.plot(x, y2, label='y=x^2', linewidth=2, color='blue', linestyle='-')

plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('Two Functions')
plt.legend()
plt.xlim((-1, 2))
plt.ylim((-2, 3))
plt.grid()
plt.show()

# %%
# matplotlib.pyplot.plot
#https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot


import numpy as np
import matplotlib.pyplot as plt

t = np.arange(0, 5, 0.2)
# 正弦波
y1 = np.sin(2 * np.pi * t)
# 指數衰減
# 請使用繁體中文
y2 = np.exp(-t)
plt.plot(t, y1, 'bo--', label='sin')
plt.plot(t, y2, 'rs--', label='exp')
plt.xlabel('時間 (秒)')
plt.ylabel('振幅')
plt.title('阻尼正弦波')
plt.legend()
plt.grid()
plt.show()
