# %%
import matplotlib as mpl
from matplotlib.font_manager import fontManager

fontManager.addfont("/Users/ylo/github/python_ai_2/1041127_lesson14/ChineseFont.ttf")
mpl.rc('font', family="ChineseFont")

# %%
# matplotlib.figure.Figure.add_subplot
# https://matplotlib.org/stable/api/_as_gen/matplotlib.figure.Figure.add_subplot.html


import matplotlib.pyplot as plt

index = ['apple', 'banana', 'orange', 'tomato', 'guava']
value = [5, 7, 3, 4, 6]
figure = plt.figure()
axes = figure.add_subplot(1,1,1) # 1 row, 1 column, first plot
axes.bar(index, value) #index為x軸, value為y軸
plt.show()

# %%
import numpy as np
# index = np.array([3, 4, 5, 6, 7])
subject = ['apple', 'banana', 'orange', 'tomato', 'guava']
value1 = [5000, 6000, 7000, 8000, 9000]
value2 = [3000, 4000, 5000, 6000, 7000]
value3 = [4000, 5000, 6000, 7000, 8000]

figure = plt.figure()
axes = figure.add_subplot()
bin_width = 0.3
axes.bar(index, value1,width=bin_width, color='red')
axes.bar(index+bin_width, value2, width=bin_width, color='blue')
axes.bar(index-bin_width, value3,width=bin_width, color='green')
axes.set_xticks(index,labels=subject)
# print(axes.get_xticks())

plt.show()

# %%
import numpy as np
index = np.array([3, 4, 5, 6, 7])
subject = ['apple', 'banana', 'orange', 'tomato', 'guava']
value1 = [5000, 6000, 7000, 8000, 9000]
value2 = [3000, 4000, 5000, 6000, 7000]
value3 = [4000, 5000, 6000, 7000, 8000]

figure = plt.figure()
axes = figure.add_subplot()
bin_width = 0.3
axes.bar(index, value1,width=bin_width, color='red')
axes.bar(index+bin_width, value2, width=bin_width, color='blue')
axes.bar(index-bin_width, value3,width=bin_width, color='green')
axes.set_xticks(index,labels=subject)

# 取得x,y軸最小,最大座標
xmin, xmax, ymin, ymax = axes.axis()
xmin -= 0.2
xmax += 0.2
ymin = 1000
ymax += 1000
axes.axis(xmin=xmin, xmax=xmax, ymin=ymin, ymax=ymax)

plt.show()

# %%
import numpy as np
index = np.array([3, 4, 5, 6, 7])
subject = ['apple', 'banana', 'orange', 'tomato', 'guava']
value1 = [5000, 6000, 7000, 8000, 9000]
value2 = [3000, 4000, 5000, 6000, 7000]
value3 = [4000, 5000, 6000, 7000, 8000]

figure = plt.figure()
axes = figure.add_subplot()
bin_width = 0.3
axes.bar(index, value1,width=bin_width, color='red')
axes.bar(index+bin_width, value2, width=bin_width, color='blue')
axes.bar(index-bin_width, value3,width=bin_width, color='green')
axes.set_xticks(index,labels=subject)

# 取得x,y軸最小,最大座標
xmin, xmax, ymin, ymax = axes.axis()
xmin -= 0.2
xmax += 0.2
ymin = 1000
ymax += 1000
axes.axis(xmin=xmin, xmax=xmax, ymin=ymin, ymax=ymax)

# 顯示legend
axes.legend(labels=['2018年', '2019年', '2020年'])

# 每個bin上顯示數值
for i in range(len(index)):
    axes.text(index[i], value1[i]+50, str(value1[i]), ha='center', va='bottom', fontsize=8)
    axes.text(index[i]+bin_width, value2[i]+50, str(value2[i]), ha='center', va='bottom', fontsize=8)
    axes.text(index[i]-bin_width, value3[i]+50, str(value3[i]), ha='center', va='bottom', fontsize=8)

plt.show()
