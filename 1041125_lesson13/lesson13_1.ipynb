# %%
print("hello world")
# Out:
# 執行具有 'python_ai_2 (Python 3.11.14)' 的儲存格需要 ipykernel 套件。
#
# 將 'ipykernel' 安裝到 Python 環境中。
#
# 命令: '/Users/ylo/github/python_ai_2/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
